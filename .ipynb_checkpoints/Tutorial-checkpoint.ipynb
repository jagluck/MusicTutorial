# %%
import requests, json, pandas, itertools
import numpy as np

print("hello")

def send_req_name(name):
    url = 'http://musicbrainz.org/ws/2/artist/?query=artist:' + name
    headers = {'Accept': 'application/json'}
    r = requests.get(url, headers=headers)
    page = r.json()
    return page

def send_req_set(num, id):
    url = 'https://api.setlist.fm/rest/1.0/artist/' + id + '/setlists/?p=' + num
    headers = {'Accept': 'application/json', 'x-api-key': 'd65d2f04-4d2a-4354-b6dd-45bedf61cde1'}
    r = requests.get(url, headers=headers)
    page = r.json()
    return page

artists = ["Russ", "SZA"]

ids = []

for artist in artists:
    print(artist)
    page = send_req_name(artist)
    list = page["artists"]
    ids.append(list[0]["id"])

#ids = ["8e494408-8620-4c6a-82c2-c2ca4a1e4f12", "cc197bad-dc9c-440d-a5b5-d52ba2e14234"]

d = {'venues': []}
df = pandas.DataFrame(d)
df['cities'] = []
df['artists'] = []

for id in ids:
    i = 1
    keep_going = True
    count = 0
    cities = []
    venues = []
    artists = []
    #artist_name = ""
    while(keep_going):
        page = send_req_set(str(i), id)
        if('code' in page):
            #print("done")
            keep_going = False
        else:
            setlist = page["setlist"]
            for sets in setlist:
                artist = sets["artist"]
                artist_name = artist["name"]
                venue = sets["venue"]
                venue_name = venue["name"]
                city = venue["city"]
                name = city["name"]
                count = count + 1
                venues.append(venue_name)
                cities.append(name)
                #print(name + " - " + venue_name)
            i = i + 1

    artists = np.repeat(artist_name, len(cities)).reshape(len(cities),1)
    d = {'venues': venues}
    dft = pandas.DataFrame(d)
    dft['cities'] = cities
    dft['artists'] = artists
    df = pandas.concat([df,dft])
    
print(df)
# Out:
# hello
# coldplay
# miley cyrus
# Russ
# SZA
#                                venues           cities   artists
# 0          Estadio Ciudad de La Plata         La Plata  Coldplay
# 1          Estadio Ciudad de La Plata         La Plata  Coldplay
# 2                     Arena do Grêmio     Porto Alegre  Coldplay
# 3                      Allianz Parque        São Paulo  Coldplay
# 4                      Allianz Parque        São Paulo  Coldplay
# 5                       SDCCU Stadium        San Diego  Coldplay
# 6                           Rose Bowl         Pasadena  Coldplay
# 7                      Levi's Stadium      Santa Clara  Coldplay
# 8                         Moda Center         Portland  Coldplay
# 9                    BC Place Stadium        Vancouver  Coldplay
# 10                       Rogers Place         Edmonton  Coldplay
# 11                       Rogers Place         Edmonton  Coldplay
